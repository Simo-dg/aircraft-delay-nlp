# %%
# Aircraft Delay Log - EDA & Preprocessing

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('../data/synthetic_logs.csv')
print(df.head())

# Basic stats
print(df['label'].value_counts())

# Visualize label distribution
plt.figure(figsize=(8,5))
sns.countplot(data=df, x='label', order=df['label'].value_counts().index)
plt.title('Distribution of Delay Categories')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
#                                             log_text            label  \
# 0  Passenger screening issue caused departure gat...         SECURITY
# 1  Security clearance delay due to unattended bag...         SECURITY
# 2  Crew rest requirements caused delay in dispatc...       CREW_DELAY
# 3  Missing ground power unit required last-minute...  LOGISTICS_ISSUE
# 4  Crew rest requirements caused delay in dispatc...       CREW_DELAY
#
#   component phase severity
# 0       NaN   NaN   medium
# 1       NaN   NaN     high
# 2       NaN   NaN   medium
# 3       NaN   NaN   medium
# 4       NaN   NaN   medium
# label
# ATC_RESTRICTION      58
# SECURITY             54
# CREW_DELAY           53
# TECHNICAL_FAILURE    49
# LOGISTICS_ISSUE      44
# WEATHER              42
# Name: count, dtype: int64
